# %%
# from IPython.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))

# import the main functions in the jupyter notebook
import sys
sys.path.append('/Users/floorbroekgaarden/Projects/GitHub/Binary_Stellar_Animation/.')
from compas_animation import *
# import pandas as pd
# Out:
# <style>.container { width:100% !important; }</style>

# %%
## run the main function from jupyter notebook
# Out:
# /Users/floorbroekgaarden/Projects/GitHub/Binary_Stellar_Animation

# %%
main()
# Out:
# Saved interpolated CSV data to /Users/floorbroekgaarden/Projects/GitHub/Binary_Stellar_Animation/compas_processed.csv
# Saving animation to /Users/floorbroekgaarden/Projects/GitHub/Binary_Stellar_Animation/binary_evolution_animation.mp4
